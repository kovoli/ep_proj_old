# %%
import xmltodict
import pprint
import json
import os
os.getcwd()
# Out:
# '/Users/imac/Desktop/ep_proj/shop/importer'

# %%
with open('cat_bit_tehnika.xml') as fd:
    doc = xmltodict.parse(fd.read())

# %%
print(json.dumps(doc['categories'], ensure_ascii=False))
# Out:
# {"category": [{"@id": "1133722", "#text": "Бытовая техника"}, {"@id": "1155469", "@parentId": "1133722", "#text": "Климатическая техника"}, {"@id": "1133729", "@parentId": "1155469", "#text": "Вентиляторы"}, {"@id": "1162507", "@parentId": "1155469", "#text": "Воздухоочистители"}, {"@id": "1133727", "@parentId": "1155469", "#text": "Обогреватели"}, {"@id": "1133728", "@parentId": "1155469", "#text": "Увлажнители воздуха"}, {"@id": "1155473", "@parentId": "1133722", "#text": "Красота и здоровье"}, {"@id": "1133723", "@parentId": "1155473", "#text": "Бритвы"}, {"@id": "1133736", "@parentId": "1155473", "#text": "Выпрямители и щипцы для волос"}, {"@id": "1196946", "@parentId": "1155473", "#text": "Косметологические аппараты"}, {"@id": "1133737", "@parentId": "1155473", "#text": "Машинки для стрижки"}, {"@id": "1182335", "@parentId": "1155473", "#text": "Триммеры"}, {"@id": "1133739", "@parentId": "1155473", "#text": "Фены"}, {"@id": "1133741", "@parentId": "1155473", "#text": "Эпиляторы
# ...

# %%
del doc['categories']['category']
for i in doc['categories']['category']:
    print(i['@parentId'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-9c3c4719e62b> in <module>
# ----> 1 del doc['categories']['category']['#text']['Бытовая техика']
#       2 for i in doc['categories']['category']:
#       3     print(i['@parentId'])
#
# TypeError: list indices must be integers or slices, not str
