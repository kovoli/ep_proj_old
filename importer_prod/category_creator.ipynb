# %%
import xml.etree.ElementTree as ET 
tree = ET.parse('shop/importer/cat_bit_tehnika.xml')
root = tree.getroot()

# %%
for elem in root:
# Out:
#   File "<ipython-input-10-525500fc089b>", line 1
#     for elem in root:
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
print(len(root))
# Out:
# 118
